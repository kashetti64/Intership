# %% [markdown]
# # List

# %%
l = [12,13,14,15]

# %%
print(l)
# Out:
# [12, 13, 14, 15]

# %%
type(l)
# Out:
# list

# %%
#list are hetrogeneous and also mutable and dublicates are alllowes

# %%
l1 = [12,78,98,65.98,88.9,78,"Hello","java",12,78]

# %%
print(l1)
# Out:
# [12, 78, 98, 65.98, 88.9, 78, 'Hello', 'java', 12, 78]

# %%
l1
# Out:
# [12, 78, 98, 65.98, 88.9, 78, 'Hello', 'java', 12, 78]

# %%
#list are ordered

# %%
l1[3]
# Out:
# 65.98

# %%
l1[6]
# Out:
# 'Hello'

# %%
l1[-3]
# Out:
# 'java'

# %%
l1[2] = 12

# %%
l1
# Out:
# [12, 78, 12, 65.98, 88.9, 78, 'Hello', 'java', 12, 78]

# %%
l1[-3] = True

# %%
l1
# Out:
# [12, 78, 12, 65.98, 88.9, 78, 'Hello', True, 12, 78]

# %%
#list slicing

# %%
l = [1,2,3,6,5,4,78,9]

# %%
l
# Out:
# [1, 2, 3, 6, 5, 4, 78, 9]

# %%
l [1:4]
# Out:
# [2, 3, 6]

# %%
l[1:-4]
# Out:
# [2, 3, 6]

# %%
l[0:5:2]
# Out:
# [1, 3, 5]

# %%
l[::2]
# Out:
# [1, 3, 5, 78]

# %%
#reverse the list

# %%
l[::-1]
# Out:
# [9, 78, 4, 5, 6, 3, 2, 1]

# %%
l[1:5] = [1,2,1,1]

# %%
l
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9]

# %%
del l1[-7]

# %%
l1
# Out:
# [12, 78, 12, 88.9, 78, 'Hello', True, 12, 78]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15880/2585568370.py in <module>
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
#membership oprators

# %%
l
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9]

# %%
1 in l
# Out:
# True

# %%
23 in l
# Out:
# False

# %%
#arithmetic oprators

# %%
l * 2 #repetition of list
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9, 1, 1, 2, 1, 1, 4, 78, 9]

# %%
l + [12,13,14]
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9, 12, 13, 14]

# %%
l
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9]

# %%
l1 = [13,15,8]

# %%
#take two different list and add them

# %%
l+l1
# Out:
# [1, 1, 2, 1, 1, 4, 78, 9, 13, 15, 8]

# %%
##iteration over list

# %%
l 
for i in l :
    print(i**2)
# Out:
# 1
# 1
# 4
# 1
# 1
# 16
# 6084
# 81

# %%
#print odd numbers in list

# %%
for i in l :
    if i%2 != 0 :
        print(i)
# Out:
# 1
# 1
# 1
# 1
# 9

# %%
#list compression -> [expression for_loop if condition]

# %%
newl = [i**2 for i in l]

# %%
newl
# Out:
# [1, 1, 4, 1, 1, 16, 6084, 81]

# %%
newl1= [i for i in l if i %2 ==1]

# %%
print(newl1)
# Out:
# [1, 1, 1, 1, 9]

# %%
name= ['Aarya','atherv','samruddhi','swaraj','Sukanya','Shivraj']

# %%
#create a new list with names with which starts with capital s or small s

# %%
name
# Out:
# ['Aarya', 'atherv', 'samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
for i in name :
    if i[0] == 'S' :
        print("capital names S")
    else :
        print("small")
# Out:
# small
# small
# small
# small
# capital names S
# capital names S

# %%
names = [i for i in name if i[0] == 'S'or i[0] == 's' ]

# %%
names
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
for i in  names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# Shivraj

# %%
new = [i for i in names if i.lower().startswith('s')]

# %%
new
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'Shivraj']

# %%
len(l)
# Out:
# 8

# %%
max(l)
# Out:
# 78

# %%
min(l)
# Out:
# 1

# %%
sorted(l)
# Out:
# [1, 1, 1, 1, 2, 4, 9, 78]

# %%
sorted(l,reverse = True)
# Out:
# [78, 9, 4, 2, 1, 1, 1, 1]

# %% [markdown]
# # list methods

# %%
l1 = [12,57,34,97,94]

# %%
#append

# %%
l1.append(88)

# %%
l1
# Out:
# [12, 57, 34, 97, 94, 88, 88]

# %%
l2 = [12,57,34,97,94]

# %%
l1.append([10,20]) #multiple value in single list get added
l2.extend([10,20]) #individual element get added

# %%
l1
# Out:
# [12,
#  57,
#  34,
#  97,
#  94,
#  88,
#  88,
#  [100, 200],
#  [100, 200],
#  [100, 200],
#  [100, 200],
#  [10, 20]]

# %%
l2
# Out:
# [12, 57, 34, 97, 94, 100, 200, 100, 200, 100, 200, 100, 200, 10, 20]

# %%
l1[-1]
# Out:
# [100, 200]

# %%
l1[8][1]
# Out:
# 200

# %%
l.insert(1,23)

# %%
l
# Out:
# [1, 23, 1, 2, 1, 1, 4, 78, 9]

# %%
l.remove(1)

# %%
l
# Out:
# [23, 1, 2, 1, 1, 4, 78, 9]

# %%
#pop

# %%
l.pop()
# Out:
# 9

# %%
l.pop(1)
# Out:
# 1

# %%
l
# Out:
# [23, 2, 1, 1, 4, 78]

# %%
#push

# %%
l.index(78)
# Out:
# 5

# %%
l.sort()

# %%
l
# Out:
# [1, 1, 2, 4, 23, 78]

# %%
l.sort(reverse = True)

# %%
l
# Out:
# [78, 23, 4, 2, 1, 1]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
