# %%
name = "Nitiesh"

# %%
name.lower()
# Out:
# 'nitiesh'

# %%
name = name.lower()

# %%
name
# Out:
# 'nitiesh'

# %%
name.upper()
# Out:
# 'NITIESH'

# %%
name.title()
# Out:
# 'Nitiesh'

# %%
name="Nitish"

# %%
name.swapcase()
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name.isdigit()
# Out:
# False

# %%
name1.isalnum()
# Out:
# True

# %%
name2.isalnum()
# Out:
# True

# %%
name.isalnum()
# Out:
# True

# %%
name="charoli"

# %%
print(name)
# Out:
# charoli

# %%
name.startswith("P")
# Out:
# False

# %%
name.endswith("L")
# Out:
# False

# %%
name.endswith("Charoli")
# Out:
# False

# %%
name.endswith("charoli")
# Out:
# True

# %%
name.endswith("l")
# Out:
# False

# %%
name.endswith("il")
# Out:
# True

# %%
name.endswith("")
# Out:
# True

# %%
name.lsstrip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9152/2585368982.py in <module>
# ----> 1 name.lsstrip()
#
# AttributeError: 'str' object has no attribute 'lsstrip'

# %%
name.lstrip()
# Out:
# 'charolil'

# %%
name.rstrip()
# Out:
# 'charolil'

# %%
len(name)
# Out:
# 8

# %%
name.replace('l', ' ')
# Out:
# 'charo i '

# %%
name.replace('a','p')
# Out:
# 'chproli'

# %% [markdown]
# # Operators

# %%
#arithmetic oprators
a=5
b=17

# %%
a+b
# Out:
# 22

# %%
a-b
# Out:
# -12

# %%
a*b
# Out:
# 85

# %%
b/a
# Out:
# 3.4

# %%
a**b # raise to opraters
# Out:
# 762939453125

# %%
b//a #floor div
# Out:
# 3

# %%
b%a
# Out:
# 2

# %%
# assignment oprators

# %%
z=5

# %%
z
# Out:
# 5

# %%
z=z+3

# %%
z
# Out:
# 8

# %%
z+=3

# %%
z
# Out:
# 11

# %%
z=11

# %%
z *= 3

# %%
z
# Out:
# 297

# %%
z*=2

# %%
z
# Out:
# 594

# %%
#comparisien  oprator

# %%
a=2
b=3

# %%
a*b
# Out:
# 6

# %%
a==b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
b>a
# Out:
# True

# %%
#logical oprators

# %%
a=2
b=3

# %%
print(a>b and b>a)
# Out:
# False

# %%
print(a>b or b>a)
# Out:
# True

# %%
print (not(a>10))
# Out:
# True

# %%
not b
# Out:
# False

# %%
not a
# Out:
# False

# %%
#identity oprators ->is ,is not

# %%
a=5
b = 5

# %%
id(a),id (b)
# Out:
# (2105414347184, 2105414347184)

# %%
a is b
# Out:
# True

# %%
a = [3,4]
b = [3,4]

# %%
id(a)
# Out:
# 2105492707520

# %%
id(b)
# Out:
# 2105492705664

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z=a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(5)

# %%
a
# Out:
# [3, 4, 5]

# %%
z
# Out:
# [3, 4, 5]

# %%
#membership oprators

# %%
l = [2,4,6,7,8,9]

# %%
6 in l
# Out:
# True

# %%
2in l
# Out:
# True

# %%
0 in l
# Out:
# False

# %%
0 not in l
# Out:
# True

# %% [markdown]
# # precendence and association

# %%
#BODOMAS RULE

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 -2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right hand association
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
2 ** 3 / 2
# Out:
# 4.0

# %%
2**3//2
# Out:
# 4

# %%
#print function

# %%
name = "sukanya"

# %%
marks = 87.60

# %%
# my name is sukanya and marks are 87.60

# %%
print("my name is",name "and my marks are",marks)
# Out:
#   File "C:\Users\Pornima\AppData\Local\Temp/ipykernel_9152/692587996.py", line 1
#     print("my name is",name "and my marks are",marks)
#                             ^
# SyntaxError: invalid syntax

# %%
print("my name is",name,"and my marks are",marks)
# Out:
# my name is sukanya and my marks are 87.6

# %%
print("my name is %s and marks are %f"%(name,marks))
# Out:
# my name is sukanya and marks are 87.600000

# %%
print(f "my name is {name}and marks are{marks}") #space not allowed near f
# Out:
#   File "C:\Users\Pornima\AppData\Local\Temp/ipykernel_9152/2628954182.py", line 1
#     print(f "my name is {name}and marks are{marks}")
#             ^
# SyntaxError: invalid syntax

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is sukanya and marks are 87.6

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("s")
# Out:
# 115

# %%
chr(64)
# Out:
# '@'

# %%
chr(31)
# Out:
# '\x1f'

# %%
#Type casting

# %%
num1 = 34
num2 = 44.56
num3 = "ok"

# %%
type(num1)
# Out:
# int

# %%
float (num1)
# Out:
# 34.0

# %%
type(num1)
# Out:
# int

# %%
int ( num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
#user input

# %%
a = input("enter nameeeeeeeeeee or number")
# Out:
# enter nameeeeeeeeeee or number53

# %%
a = input ("enter number")
# Out:
# enter number9

# %%
print("ok")
# Out:
# ok

# %%
# writing program for addition of two number using user input

# %%
a =int(input("enter a "))
b= int(input("enter b "))
z=a+b
print("Addition is ",z)
# Out:
# enter a 5
# enter b 7
# Addition is  12

# %%
# read the time time in seconds as user input AND print the time in the format as 
#as hour:minutes:second

# %%
seconds=int(input("enter time in second:="))
hours = seconds // 3600
minutes = (seconds % 3600) // 60
seconds = seconds % 60
print("hour:",hours,"minutes:",minutes,"seconds",seconds)
# Out:
# enter time in second:=40002
# hour: 11 minutes: 6 seconds 42
