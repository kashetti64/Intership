# %%
send = "hello world!"

# %%
send
# Out:
# 'hello world!'

# %%
send = "Hello World !"

# %%
send
# Out:
# 'Hello World !'

# %%
# docstring

# %%
send = """This is multi line string
It can span multiple lines
It is used for doc string

"""

# %%
print(send)
# Out:
# This is multi line string
# It can span multiple lines
# It is used for doc string

# %%
send[0]
# Out:
# 'T'

# %%
send[0:5]
# Out:
# 'This '

# %%
""" Take a string as user input
print the output => index and charater
""";

# %%
string = str(input("enter a charater"))
for i in string:
    print(f"{string.index(i)} => {i}")
#print(string.index(string))
# Out:
# enter a charaterThis is string
# 0 => T
# 1 => h
# 2 => i
# 3 => s
# 4 =>
# 2 => i
# 3 => s
# 4 =>
# 3 => s
# 9 => t
# 10 => r
# 2 => i
# 12 => n
# 13 => g

# %%
send = "ajit kumar;age :25 ; city :delhi ; hobby :coading"

# %%
type(send)
# Out:
# str

# %%
send.split(";")
# Out:
# ['ajit kumar', 'age :25 ', ' city :delhi ', ' hobby :coading']

# %%
send.find("kumar")
# Out:
# 5

# %%
send.find("k")
# Out:
# 5

# %%
s1 = "hello"

# %%
s1.find("l")
# Out:
# 2

# %%
s1.index("o")
# Out:
# 4

# %%
#split => it split the string based on the given delimeter and returns a list substring

#join -> opposite of split

# %%
l= ["hello","world", "python"]

# %%
' '.join(l)
# Out:
# 'hello world python'

# %%
'=='.join(l)
# Out:
# 'hello==world==python'

# %%
# user ->string 
# uing loop split into individual chracter and store in  a list

# %%
l1 = str(input("enter a string"))
l = []
for i in l1 :
    l.append(i)
print(l)
# Out:
# enter a stringstrrr
# ['s', 't', 'r', 'r', 'r']

# %%
"""
take a string as user input 
use a loop and if-else to check if a specific character is present in
the string or not
get output for both if the char is present and if it is not present. 
take 2 character to check in the string

user input => string , character1, character2
""";

# %%
s1 = str(input("enter a 1st string:="))
char = input("enter a character:=")
char1 = str(input("enter a character:="))
flag1 = False
Flag2 = False
for i in s1 :
    if i == char:
        flag1 = True
    if  i == char1:
        flag2 =True
if flag1 :
    print(f"The char '{char}'is presnt in string ")
else :
    print(f"The char '{char}' is not present")
          
if flag2 :
    print(f"The char '{char1}' is present in string" )
else :
    print(f"The char '{char1}' is not present in string" )
# Out:
# enter a 1st string:=stop
# enter a character:=o
# enter a character:=p
# The char 'o'is presnt iin string
# The char 'p' is present in string

# %%
#escape sequence

# %%
print("i like python programming \nits easy to learn")
# Out:
# i like python programming
# its easy to learn

# %%
print("i like python programming \tits easy to learn")
# Out:
# i like python programming 	its easy to learn

# %%
print("i like python programming \\ its easy to learn")
# Out:
# i like python programming \ its easy to learn

# %%
print("i like python programming  \"its easy to learn")
# Out:
# i like python programming  "its easy to learn

# %%
name = "sukanya"
marks = 79

# %%
"my name is {} and my marks are {}".format(name,marks)
# Out:
# 'my name is sukanya and my marks are 79'

# %%
"""
Vowel Counter:
Write a Python function that takes a string as input. Using a for loop, 
iterate through each character. If the character is a vowel 
(a, e, i, o, u, case-insensitive),
increment a counter. Store the count of each vowel in a 
dictionary. Finally, print
the total number of vowels found and the dictionary of vowel counts
""";

# %%
count=0
stri = str(input("enter a string "))
vowel= {'a':0,'e':0,'i':0,'o':0,'u':0}

for i in stri :
    i= i.lower()
    if  i in vowel :
        count=+1 
        vowel[i]=+1
print(f"Total vowel {count}")
print("vowel count",vowel)
# Out:
# enter a string AIshwarya
# Total vowel 1
# vowel count {'a': 1, 'e': 0, 'i': 1, 'o': 0, 'u': 0}

# %%
"""
Palindrome Checker with List:
Write a Python function that accepts a string. Inside the function, 
use a for loop to build a new list containing the characters of the string 
in reverse order. Then, use an if-else statement to check if the original
string is a palindrome (reads the same forwards and backward) by comparing
it to the string formed from the reversed list. Print whether the string 
is a palindrome or not.
""";

# %%
"""
count = []
pal = input("enter a string")
pal1=pal[::-1]
for i in pal1:
    print(pal1)
    if pal==pal1:
        print("palindrome")
    else:
        print("not a plaindrome")
""";

# %%
pal = input("Enter a string: ")

rev = []

for i in pal:
    rev.insert(0, i)

rev_str = "".join(rev)

if pal == rev_str:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a string: pap
# Palindrome

# %%
"""
Character Frequency Counter:
Create a Python function that takes a string. Use a for loop to iterate
through the string and populate a dictionary where keys are characters and
values are their frequencies. Use an if-else statement to handle whether a
character is already in the dictionary or not. Print the resulting character 
frequency dictionary.
""";
