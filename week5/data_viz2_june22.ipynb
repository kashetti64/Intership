# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([10, 23, 29, 34, 39, 45, 50])
y = np.array([14, 21, 31, 43, 48, 55, 58])
z = np.array([56, 50, 44, 37, 26, 20, 16])

# %% [markdown]
# # Line chart

# %%
plt.plot(x,y);

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart : x vs y")
plt.plot(x,y);

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart : x vs y")
plt.plot(x,y, marker = 'o',mfc = 'green' , ls = '--');
plt.grid();

# marker = o,*,H,<,>, ^

# %%
plt.xlabel("x values")
plt.ylabel("z values")
plt.title("line chart : x vs z")
plt.plot(x,y, marker = 'o' , mfc ="red" , ls='--', label = "2024");
plt.plot(x,z, marker = 'o',mfc = 'blue' , ls = '--', label = '2025');
plt.grid();
plt.legend();

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize= (16,9))

plt.subplot(2,2,1)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart : x vs y")
plt.plot(x,y, marker = 'o',mfc = 'green' , ls = '--');
plt.grid();

plt.subplot(2,2,2)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart : x vs y")
plt.plot(x,z, marker = 'o',mfc = 'green' , ls = '--');
plt.grid();

# %% [markdown]
# # Bar chart

# %%
courses = ['python','lisp','c','r','php']
students = [68,30,78,37,70]

# %%
plt.bar(courses,students)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title("students enrollment")
plt.xlabel("course")
plt.ylabel("no.of students enrolled")

plt.bar(courses,students,color ='brown',edgecolor = 'black');

# %%
df = pd.read_csv("student.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.title("Student name vs marks with proper label")
plt.ylabel("marks")
plt.xlabel("student name")
plt.xticks(rotation = 45)
plt.bar(df['name'], df['marks'],color = 'red')
# Out:
# <BarContainer object of 10 artists>

# %%
# plot bar graph showing the count of how many people purchased and how 
#many did not

# purchased columns => 0 purchased 1 -> not purchased

# %%
df = pd.read_csv("Social_Network_Ads.csv")
plt.ylabel("no. of purchased")
plt.xlabel("gf")
counts = df["Purchased"].value_counts()
plt.bar(["Purchased", "Not Purchased"],
        [counts[0], counts[1]],
        color=["green", "red"])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(df['Purchased'].value_counts().index, df['Purchased'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Scatter chart

# %%
plt.scatter(x,y, color = 'red')

# %%
plt.figure(figsize = (16,10))
plt.scatter(df['Age'],df['EstimatedSalary'], c= df['Purchased']);

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue = 'species');

# %%
# univariate analysis
plt.xticks(range(0,70,2),rotation =45)
plt.yticks(range(0,70,5))
plt.hist(df['Age'], bins =15);

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
# for the age col, on put the following values at that index

# 2 -> 8, 3 -> 85

# %%
df['Age'][2] = 5
df['Age'][3] = 85
# Out:
# C:\Users\Pornima\AppData\Local\Temp/ipykernel_2012/461869127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][2] = 5
# C:\Users\Pornima\AppData\Local\Temp/ipykernel_2012/461869127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][3] = 85

# %%
plt.boxplot(df['Age']);

# %%
import numpy as np

def remove_outliers(df):
    q1 = np.percentile(df["Age"], 25)
    q3 = np.percentile(df["Age"], 75)

    iqr = q3 - q1

    lb = q1 - 1.5 * iqr
    ub = q3 + 1.5 * iqr

    df = df[(df["Age"] >= lb) & (df["Age"] <= ub)]

    return df

df = remove_outliers(df)

plt.boxplot(df["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28697178d90>,
#   <matplotlib.lines.Line2D at 0x28697187160>],
#  'caps': [<matplotlib.lines.Line2D at 0x286971874f0>,
#   <matplotlib.lines.Line2D at 0x28697187760>],
#  'boxes': [<matplotlib.lines.Line2D at 0x286971789d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28697187af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28697187e80>],
#  'means': []}

# %%
# practice =>
# load the tips dataset from seaborn
# do detailed EDA (charts along with explaination of what we r understanding from them)
# u can use official documentation for ref

# %%
sns.load_dataset("tips")
# Load Dataset
df = sns.load_dataset("tips")
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())

# Histrogram
plt.figure(figsize= (6,5))
plt.hist(df['total_bill'],bins = 19)
plt.xlabel("bill")
plt.ylabel("frequency")
plt.show()

# scattter
plt.figure(figsize= (6,4))
plt.scatter(df["total_bill"],df["tip"])
plt.title("Total Bill vs Tip")
plt.xlabel("Total bill")
plt.ylabel("Total tip")

#box plot
plt.figure(figsize= (6,4))
plt.boxplot(df['size'])
plt.title("Box Plot of size")

#bar plot
plt.figure(figsize= (6,4))
plt.title("Average Tip by Gender")
sns.barplot(x='sex',y='tip',data=df)
plt.show()

#pair plot
sns.pairplot(df, hue ='smoker')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64
# 1
