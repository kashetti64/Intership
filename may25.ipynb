# %%
print("hello World")
# Out:
# hello World

# %%
#above ->A, below ->B delete ->x

# %% [markdown]
# # Identifiers

# %%
num = 56

# %%
num1= 8

# %%
name = "riya"

# %%
print(name)
# Out:
# riya

# %%
name
# Out:
# 'riya'

# %%
rate = 5

# %%
rate
# Out:
# 5

# %%
Pass =4

# %%
Pass
# Out:
# 4

# %%
l= [3]

# %%
type(l)
# Out:
# list

# %%
num =10

# %%
num2=20.54

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
name="aunty"

# %%
type(name)
# Out:
# str

# %%
#float
num =23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0

# %%
#string
send ="i like python programming"

# %%
sent = 'I like "Python" Programming'
print(sent)
# Out:
# I like "Python" Programming

# %%
send
# Out:
# 'i like python programming'

# %%
sent = "I like 'Python' Programming"
print(sent)
# Out:
# I like 'Python' Programming

# %%
print(send)
# Out:
# i like python programming

# %%
a = 3
b = 5
z = a + b
print(z)
# Out:
# 8

# %%
a = 3; b = 5; z = a + b; print(z);
# Out:
# 8

# %%
a, b, c = 23, 56, "ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'
