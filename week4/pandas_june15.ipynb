# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.9 MB 15.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 17.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 13.7 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.0 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
# ...

# %%
# 1D datastructure in pandas

# %%
# pandas series

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
d = pd.Series([10,20,30], index = ['a','b','c'])

# %%
d
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s = pd.Series(['sukanya',90,18], index = ['name','marks','age'])

# %%
s
# Out:
# name     sukanya
# marks         90
# age           18
# dtype: object

# %%
#from dictionary

# %%
data = {'name':'sukanya','age ':18,'marks':89}

# %%
data
# Out:
# {'name': 'sukanya', 'age ': 18, 'marks': 89}

# %%
s = pd.Series(data)

# %%
s
# Out:
# name     sukanya
# age           18
# marks         89
# dtype: object

# %%
s1 = {'name':'sukanya','age':19,'marks':90}

# %%
s = pd.Series(s1)

# %%
s
# Out:
# name     sukanya
# age           19
# marks         90
# dtype: object

# %%
# from a single value

# %%
s = pd.Series(5,index = [0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
# Attributes of series

# %%
s = pd.Series([10,20,30],index = ['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='str')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 3

# %%
s.shape
# Out:
# (3,)

# %%
# Data manipulation

# %%
s= pd.Series([1,2,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s*3
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling missing vallues

# %%
s = pd.Series([112,None,3])

# %%
s
# Out:
# 0    112.0
# 1      NaN
# 2      3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    112.0
# 2      3.0
# dtype: float64

# %%
s.fillna(23)
# Out:
# 0    112.0
# 1     23.0
# 2      3.0
# dtype: float64

# %%
# indexing

# %%
s= pd.Series([12,24,36],index = ['a','b','c'])

# %%
s
# Out:
# a    12
# b    24
# c    36
# dtype: int64

# %%
s['a']
# Out:
# np.int64(12)

# %%
s['c']
# Out:
# np.int64(36)

# %%
s['b']
# Out:
# np.int64(24)

# %%
import numpy as np

# %%
a = np.array([2, 44.5, True, 'aryan'])

# %%
a
# Out:
# array(['2', '44.5', 'True', 'aryan'], dtype='<U32')
