# %%
"""
create a sample text file with some text in it
""";

# %%
f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable() #it read line by line and execute each line
# Out:
# True

# %%
f.readline()
# Out:
# 'Write a function that takes two strings as input.\n'

# %%
f.readline(10)
# Out:
# 'Convert bo'

# %%
f.readline(5)
# Out:
# 'th st'

# %%
f.readlines()
# Out:
# ['rings into lists of\n', 'characters.\n', '\n', ' done\n', ' done']

# %%
f=open("sample.txt")

# %%
data= f.readlines()

# %%
data
# Out:
# ['Write a function that takes two strings as input.\n',
#  'Convert both strings into lists of\n',
#  'characters.\n',
#  '\n',
#  ' done\n',
#  ' done']

# %%
for line in data:
    print(line)
# Out:
# Write a function that takes two strings as input.
#
# Convert both strings into lists of
#
# characters.
#
#
#
#  done
#
#  done

# %%
for line in data:
    print(line.upper())
# Out:
# WRITE A FUNCTION THAT TAKES TWO STRINGS AS INPUT.
#
# CONVERT BOTH STRINGS INTO LISTS OF
#
# CHARACTERS.
#
#
#
#  DONE
#
#  DONE

# %%
# read function

# %%
f=open("sample.txt")

# %%
text = f.read()

# %%
text
# Out:
# 'Write a function that takes two strings as input.\nConvert both strings into lists of\ncharacters.\n\n done\n done'

# %%
print(text)
# Out:
# Write a function that takes two strings as input.
# Convert both strings into lists of
# characters.
#
#  done
#  done

# %%
text.split()
# Out:
# ['Write',
#  'a',
#  'function',
#  'that',
#  'takes',
#  'two',
#  'strings',
#  'as',
#  'input.',
#  'Convert',
#  'both',
#  'strings',
#  'into',
#  'lists',
#  'of',
#  'characters.',
#  'done',
#  'done']

# %%
m = open("marathi.txt",encoding= 'utf-8')

# %%
print(m.read())
# Out:
# राजराजा चोळने इ.स. १००३ ते १०१० या दरम्यान हे मंदिर बांधले व त्याला राजराजेश्वरम असे नाव दिले.
# मंदिरातील नंतरच्या शिलालेखात मंदिराच्या देवतेला पेरिया उदैया नायनार असे संबोधले आहे,
# जे बृहदेश्वर आणि पेरुवुदैयार कोविल या आधुनिक नावांचे उगमस्थान असल्याचे मानले जाते.

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24588/787536634.py in <module>
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
#opening a file with context manager

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
f.closed
# Out:
# True

# %%
print(data)
# Out:
# Write a function that takes two strings as input.
# Convert both strings into lists of
# characters.
#
#  done

# %%
# writing in a file

# %%
f = open("myfile.text.txt",'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines = ['darla tool a ring ', "he started his journey to mount dooom."]

# %%
f.writelines(lines)

# %%
f.close()

# %%
#writelines -> takes the list of sentances from user and write them in the files

# %%
#write

# %%
send = "darla tool a ring he started his journey to mount dooom."

# %%
f = open('myfile.text.txt','w')
f.write(send)
f.close()

# %%
#write into a myfile with context manager
#use write function and add 3 separate lines

# %%
with open('myfile.txt','w') as f:
    f.write("this is 1st line\n")
    f.write("this is 2nd line\n")
    f.write("this is 3rd line\n")
with open("myfile.txt", "r") as f:
    print(f.read())
# Out:
# this is 1st line
# this is 2nd line
# this is 3rd line

# %%
#send = "A Context Manager in Python is used to automatically manage resources such as files"

# %%
s = open ("sample.txt","r")
f = open ("myfile.txt","w")

# %%
contents = s.read()
f.write(contents)
f.close()

# %%
s = open("sample.txt",'a')

# %%
s.write("\n done")
# Out:
# 6

# %%
s.close()

# %%
f =open("sample.txt")

# %%
f.readline(10)
# Out:
# 'Write a fu'

# %%
f.readline(5)
# Out:
# 'nctio'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(10)
# Out:
# 'nction tha'
